# %% [markdown]
# <a href="https://colab.research.google.com/github/Purushottamlpa/test-1_-MLOPs-B3/blob/main/sk_learn_30th_March.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#download data and keep as local copy in sample data
# !wget -qq https://cdn.iisc.talentsprint.com/AIandMLOps/Datasets/data1.txt

# %%
data = pd.read_csv("/content/data1.txt", header=None)
#parameter inplace means, make permanent changes to dataset
data.rename(columns={0:"Visitor count", 1: "Revenue Count"}, inplace = True)
data.head()
# Out:
#    Visitor count  Revenue Count
# 0         6.1101        17.5920
# 1         5.5277         9.1302
# 2         8.5186        13.6620
# 3         7.0032        11.8540
# 4         5.8598         6.8233
